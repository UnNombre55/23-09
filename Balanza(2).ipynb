# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,] 
y = [2.958	,2.928	,3.263	,2.997	,3.248	,3.100	,3.046	,3.216	,3.313	,3.292]

# %%
plt.figure(figsize=(10,6))
plt.plot(x,y, marker='o',linestyle='--',color='b')
plt.xlabel("Años")
plt.ylabel("Muertes")
plt.title("TASA DE SUICIDIOS")
plt.xticks(x)
plt.show()
