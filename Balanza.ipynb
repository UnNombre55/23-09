# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['Licenciatura en Finanzas','Ingeniería Petrolera','Sistemas e Informática','Ingeniería Industrial','Ingeniería Electrónica']
y = [214.062, 254.00 , 184.800,171.416,168.676]

# %%
plt.figure(figsize=(20,6))
plt.title("Trabaos en argentina")
plt.xlabel('Puesto de trabajos')
plt.ylabel("Sueldo")
sns.barplot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
